# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import torch as tr
from torch import nn
import torch.nn.functional as F

# %%
##applied dense for linear,sigmoid and softmax activations
def Dense(input,neurons,activation='linear'):
    m=input.shape[1]
    n=neurons
    W=tf.random.normal((m,n))
    B=tf.random.normal((1,n))

    output=tf.add(tf.matmul(input,W),B)
    if activation=='linear':
        return output

    if activation=='sigmoid':
        return tf.nn.sigmoid(output)
    
    if activation=='softmax':
        return tf.nn.softmax(output)

# %%
def Dense(input,neurons,activation='linear'):
    m=input.shape[1]
    n=neurons
    W=tr.randn(m,n)
    B=tr.randn(1,n)

    output=input @ W + B

    if activation=='linear':
        return output

    if activation=='sigmoid':
        return F.sigmoid(output)
    
    if activation=='softmax':
        return F.softmax(output)
